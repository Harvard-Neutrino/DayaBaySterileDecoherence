# %%
import sys
import os
common_dir = '/Common_cython'
main_dir = os.getcwd()[:-5]
#sys.path.append(main_dir+common_dir)

import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

path_to_style = main_dir + common_dir
dir = 'PlotData/'
plt.style.use(path_to_style+r"/paper.mplstyle")
mpl.rcParams.update({'text.usetex': True})
mpl.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

color1 = '#FFB14E'
color2 = '#EA5F94'
color3 = '#0000FF'

# %%
def LogSpacePoints(Emin,Emax,binnum = 30):
	"""Returns log space points.
        
        @type   Emin     :      float
        @param  Emin     :      min value
        @type   Emax     :      float
        @param  Emax     :      max value
        
        @rtype           :      list
        @return          :      log spaced values
	"""
	E_list = []
	Emin_log, Emax_log = np.log(Emin),np.log(Emax)
	if Emin_log == -float('inf') :
		Emin_log = 0.0
	Estep_log = (Emax_log-Emin_log)/float(binnum)
	Elog = np.arange(Emin_log,Emax_log+Estep_log/2.0,Estep_log)
	for logE in Elog:
		E_list.append(np.exp(logE))
    
	return E_list

# %%
GeV = 1.0
eV = 1e-9*GeV
cm = 50677.308/eV
km = 1e5*cm
m  = 1e2*cm
nm = 1e-9*m
MeV = 1e-3*GeV

# %%
margins = dict(left=0.15, right=0.97,bottom=0.19, top=0.7)
fig,ax1 = plt.subplots(figsize = (10,7)) 

#ax1 = fig.add_subplot(111)

opa = 0.7

enu = np.logspace(np.log10(3e-4*GeV),np.log10(7*GeV),20)
Deltam21 = 7.42e-5*eV**2
Deltam31 = 2.514e-3*eV**2
Deltam41 = 1*eV**2

ax1.set_xlim(5.0e-4,0.9e3)
ax1.set_ylim(0.2e16,1.0e23)
ax1.loglog()

ax1.set_xlabel(r"$E_\nu [\mathrm{GeV}] $")
ax1.set_ylabel(r"$L\ [\mathrm{GeV}^{-1}] $")

ax1.annotate("LSND", xy = (0.05,1.7e17), size = 12)
ax1.hlines(y = 1.5e17, xmin = 1.0e-2, xmax = 0.2, lw = 2, color = '#EF597B')
ax1.hlines(y = 1.5e17, xmin = 1.0e-2, xmax = 0.2, lw = 2, color = "k", linestyle = "dashed")

ax1.annotate("NEOS", xy = (1.8e-3,26*m), size = 14)
ax1.hlines(y = 23.7*m, xmin = 1.8e-3, xmax = 1.2e-2, lw = 2, color = 'k')

ax1.annotate('Neutrino-4', xy = (0.004,9*m), size = 12)
ax1.hlines(y = 8*m, xmin = 1.8e-3, xmax = 1.2e-2, lw = 2, color = 'k')


ax1.annotate('BEST', xy = (7.2e-4,0.43*m), size = 14, zorder = 200)
ax1.hlines(y = 0.5*m, xmin = 4e-4, xmax = 7e-4, lw = 2, color = 'k')

ax1.annotate('SAGE', xy = (3.4e-4,0.78*m), size = 12)
ax1.hlines(y = 0.71*m, xmin = 4e-4, xmax = 7e-4, lw = 2, color = 'k')

ax1.annotate('GALLEX', xy = (4.5e-4,1.5*m), size = 12)
ax1.hlines(y = 2.51*m, xmin = 4e-4, xmax = 7e-4, lw = 2, color = 'k', zorder = 150)


ax1.annotate("KARMEN", xy = (0.03,5.2e16), size = 12)
ax1.hlines(y = 17.7*m, xmin = 10e-3, xmax = 200e-3, lw = 2)

ax1.annotate("OscSNS", xy = (0.03,3.5e17), size = 12)
ax1.hlines(y = 3.15e17, xmin = 0.001, xmax = 0.05, lw = 2, zorder = 3)

ax1.annotate("JUNO", xy = (0.0035,1.75e20), size = 12)
ax1.hlines(y = 3.0e20, xmin = 0.0018, xmax = 0.012, lw = 2)

ax1.annotate("Daya Bay", xy = (0.0025,11.95e18), size = 14)
ax1.hlines(y = 9.9e18, xmin = 1.8e-3, xmax = 12e-3, lw = 2)

ax1.annotate("DAE"+"$\delta$"+"ALUS", xy = (0.015,4.6e19), size = 12)
ax1.hlines(y = 4.e19, xmin = 0.01, xmax = 0.06, lw = 2)

ax1.annotate("MiniBooNE", xy = (0.2,3.3e18), size = 12)
ax1.hlines(y = 2.8e18, xmin = 0.2, xmax = 3.0, lw = 2, zorder = 3, color = '#EF597B')
ax1.hlines(y = 2.8e18, xmin = 0.2, xmax = 3.0, lw = 2, zorder = 3, color = "k", linestyle = "dashed")

ax1.annotate('MicroBooNE', xy = (0.13,280*m), size = 12)
ax1.hlines(y = 470*m, xmin = 0.2, xmax = 3.0, lw = 2, color = 'k')


ax1.annotate("CDHS", xy = (1.2,3.9e17), size = 12)
ax1.hlines(y = 6.66e17, xmin = 1.0, xmax = 3.93, lw = 2)

ax1.annotate("MINER"+r"$\nu$"+"A", xy = (1,9.5e17), size = 12)
ax1.hlines(y = 1.63e18, xmin = 1.0, xmax = 20.22, lw = 2)

ax1.annotate("BNL-E776", xy = (2,3.2e18), size = 11)
ax1.hlines(y =4.77e18, xmin = 1.0, xmax = 5.0, lw = 2)

#ax1.annotate("NOMAD/CHORUS", xy = (30,1.7e18), size = 12)
#ax1.hlines(y =2.98e18, xmin = 10.0, xmax = 155.0, lw = 2)

#ax1.annotate("CCFR/NuTeV", xy = (45,6.5e18), size = 12)
#ax1.hlines(y =5.52e18, xmin = 30.0, xmax = 605.0, lw = 2)

ax1.annotate("K2K", xy = (0.7,0.75e21), size = 12)
ax1.hlines(y =1.26e21, xmin = 0.3, xmax = 2.52, lw = 2)

ax1.annotate("T2K", xy = (0.3,1.65e21), size = 12)
ax1.hlines(y =1.42e21, xmin = 0.25, xmax = 0.81, lw = 2)

ax1.annotate("MINOS/OPERA/ICARUS", xy = (0.55,2.1e21), size = 12)
ax1.hlines(y = 3.66e21, xmin = 0.97, xmax = 31.09, lw = 2)

ax1.annotate('MINOS (near)', xy = (1.,1.3*km), size = 12)
ax1.hlines(y = 1.04*km, xmin = 0.97, xmax = 31.09, lw = 2)

ax1.annotate("NO"+r"$\nu$"+"A", xy = (2.5,4.05e21), size = 11)
ax1.hlines(y = 4.1e21, xmin = 1.63, xmax = 2.38, lw = 2)

ax1.annotate("DUNE", xy = (2,7.3e21), size = 12)
ax1.hlines(y = 6.5e21, xmin = 0.5, xmax = 7.05, lw = 2)

ax1.annotate("PROSPECT", xy = (2.4e-3,1.7e16), size = 14)
ax1.hlines(y = 3.0e16, xmin = 1.8e-3, xmax = 1.2e-2, lw = 2)

ax1.annotate("IsoDAR", xy = (1.35e-2,9.5*m), size = 10.5, color = '#cd34b5')
#ax1.hlines(y = 10*m, xmin = 3.0e-3, xmax = 1.3e-2, lw = 2)
IsoDAR_patch = mpl.patches.Rectangle(xy = (3e-3,9.5*m), width = 10e-3, height = (25.6-9.5)*m, color = '#cd34b5', alpha = opa/2)
ax1.add_patch(IsoDAR_patch)

# patches

ax1.annotate("Solar Potential", xy = (0.9e-3,3.5e22), size = 12)
rec_solar = mpl.patches.Rectangle(xy = (3.0e-4,1.5e20), width = 0.01731, height = 10.35e22, color = '#FFCB18', alpha = opa)
ax1.add_patch(rec_solar)

ax1.annotate("KamLAND", xy = (0.0013,15.0e20), size = 12)
rec_KamLAND = mpl.patches.Rectangle(xy = (0.0018,7.22e20), width = 10.2e-3, height = 5.e20, fill = None, hatch = '///')
ax1.add_patch(rec_KamLAND)

ax1.annotate("Super-K", xy = (1.3,3.5e22), size = 12)
rec_SK = mpl.patches.Rectangle(xy = (0.21,1.5e20), width = 20.5, height = 18.0e22, color = '#73B66B', alpha = opa)
ax1.add_patch(rec_SK)

#ax1.annotate("IceCube", xy = (120.0,0.9e22), rotation = 90, size = 12, fontweight = "bold")
rec_icecube = mpl.patches.Rectangle(xy = (100.0,1.5e20), width = 10000.5, height = 18.0e22, color = '#29A2C6', alpha = opa)
#ax1.add_patch(rec_icecube)

#ax1.text(50.0,0.8e22,"DeepCore",rotation=90, size = 12, fontweight = "bold")
rec_deepcore = mpl.patches.Rectangle(xy = (10.0,1.5e20), width = 10000.5, height = 18.0e22, color = '#29A2C6', 
                                     alpha = opa-0.4)
#ax1.add_patch(rec_deepcore)

ax1.annotate("Bugey", xy = (2.5e-3,4.1e17), size = 12, color = '#8E2921',fontweight = "bold")
rec_reactor_2 = mpl.patches.Rectangle(xy = (1.8e-3,0.9e17), width = 10.2e-3, height = 2.8e17, color = '#FA8775', alpha = opa)
ax1.add_patch(rec_reactor_2)

ax1.annotate(" Double Chooz \n Palo Verde \n RENO", xy = (2.0e-3,1.5e18), size = 12)
rec_reactor_1 = mpl.patches.Rectangle(xy = (1.8e-3,2.0e18), width = 10.2e-3, height = 6.6e18, color = '#FFB14E', alpha = opa)
ax1.add_patch(rec_reactor_1)

ax2 = ax1.twinx()
ax2.loglog()
ax2.set_xlim(5.0e-4,0.7e3)
ax2.set_xlim(3.0e-4,0.7e1)
ax2.set_ylim(0.2e16/(GeV*m),1.0e23/(GeV*m))
ax2.set_ylabel(r"$L\ [\mathrm{m}] $")

solar = 4*(enu)/(Deltam21)*2*np.pi
atm = 4*enu/(Deltam31)*2*np.pi
ste = 4*enu/(Deltam41)*2*np.pi

ax1.annotate(r"$L_\odot^{\text{osc}}$", xy = (0.025,2.0e22), size = 20, fontweight = "bold", color = 'gray')
#ax1.plot(EE/GeV,2.0*np.pi*(EE/dmsq_sun)*GeV, lw = 3.5, color = 'k', ls = "dashed")
ax1.plot(enu,solar, lw = 3.5, color = 'gray', ls = "dotted")

ax1.annotate(r"$L_{\text{atm}}^{\text{osc}}$", xy = (0.025,0.65e21), size = 20, fontweight = "bold", color = color2)
ax1.plot(enu,atm, lw = 3.5, color = color2, ls = "dashed")

ax1.annotate(r"$L_{\text{ste}}^{\text{osc}}$", xy = (0.5,3e19), size = 20, fontweight = "bold", color = 'gray')
ax1.plot(enu,ste, lw = 3.5, color = 'gray', ls = "dotted", zorder = 100)

sigma = 2.1e-4*nm
enu_nuc = np.logspace(np.log10(3e-4*GeV),np.log10(1.5e-2*GeV),20)
decoh = 4*np.sqrt(2)*enu_nuc**2*sigma/Deltam31
ax1.plot(enu_nuc,decoh, lw = 3.5, color = color3, ls = "dashed", zorder = 100)
ax1.fill_between(enu_nuc,decoh,1e23,color = color3, alpha = 0.05)
x1 = 1.25e-3/GeV
x2 = 7e-4/GeV
y1 = 0.4e19*GeV
y2 = 5e19*GeV
ax1.annotate(r"$L_{\text{atm}}^{\text{coh,nuc}}$", xy = (4e-4,2e18), size = 20, fontweight = "bold", color = color3)
#x1.arrow(x1,y1,x2-x1,y2-y1, length_includes_head=True,head_length= 6e15,color = color3)

#ax1.arrow(0.02,0.25e19,0,0.8e19, head_length= 6e18, color = color3)
ax1.annotate("", xy=(x1,y2), xytext=(x1,y1),arrowprops=dict(arrowstyle="->", color = color3, lw = 3), zorder = 101)
#ax1.annotate("", xy=(x2,y2), xytext=(x1,y1),arrowprops=dict(arrowstyle="->", color = color3, lw = 3))



#ax1.annotate("", xy=(0.3,0.8e23), xytext=(0.49,1.4e22),arrowprops=dict(arrowstyle="->", color = color3, lw = 3))


ax1.annotate("Nuclear decay", xy = (1e-3, 2.5e23), xycoords = 'data', annotation_clip = False)
ax1.annotate(r"$\pi$ decay"+"\n at rest", xy = (5.3e-2, 2.0e23), ha = 'right', xycoords = 'data', annotation_clip = False)
ax1.annotate(r"$\pi$ decay in flight", xy = (2.2e-1, 2.5e23), xycoords = 'data', annotation_clip = False)
ax1.annotate('', xy=(1.99e-2,1.7e23), xytext=(3.01e-4,1.7e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)
ax1.annotate('', xy=(61e-3,1.3e23), xytext=(1.01e-2,1.3e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)
ax1.annotate('', xy=(59e-3,1.7e23), xytext=(6.9e0,1.7e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)

#ax1.grid(linestyle = '-.')
plt.savefig('All_experiments_JUNO.pdf', dpi = 600, bbox_inches = 'tight')
#plt.savefig('All_experiments.png', dpi = 600, bbox_inches = 'tight')

# %%
margins = dict(left=0.15, right=0.97,bottom=0.19, top=0.7)
fig,ax1 = plt.subplots(figsize = (10,7)) 

#ax1 = fig.add_subplot(111)

opa = 0.7

enu = np.logspace(np.log10(3e-4*GeV),np.log10(7*GeV),20)
Deltam21 = 7.42e-5*eV**2
Deltam31 = 2.514e-3*eV**2
Deltam41 = 1*eV**2

ax1.set_xlim(5.0e-4,0.9e3)
ax1.set_ylim(0.2e16,1.0e23)
ax1.loglog()

ax1.set_xlabel(r"$E_\nu [\mathrm{GeV}] $")
ax1.set_ylabel(r"$L\ [\mathrm{GeV}^{-1}] $")

ax1.annotate("LSND", xy = (0.05,1.7e17), size = 12)
ax1.hlines(y = 1.5e17, xmin = 1.0e-2, xmax = 0.2, lw = 2, color = '#EF597B')
ax1.hlines(y = 1.5e17, xmin = 1.0e-2, xmax = 0.2, lw = 2, color = "k", linestyle = "dashed")

ax1.annotate("NEOS", xy = (1.8e-3,26*m), size = 14)
ax1.hlines(y = 23.7*m, xmin = 1.8e-3, xmax = 1.2e-2, lw = 2, color = 'k')

ax1.annotate('Neutrino-4', xy = (0.004,9*m), size = 12)
ax1.hlines(y = 8*m, xmin = 1.8e-3, xmax = 1.2e-2, lw = 2, color = 'k')


ax1.annotate('BEST', xy = (7.2e-4,0.43*m), size = 14, zorder = 200)
ax1.hlines(y = 0.5*m, xmin = 4e-4, xmax = 7e-4, lw = 2, color = 'k')

ax1.annotate('SAGE', xy = (3.4e-4,0.78*m), size = 12)
ax1.hlines(y = 0.71*m, xmin = 4e-4, xmax = 7e-4, lw = 2, color = 'k')

ax1.annotate('GALLEX', xy = (4.5e-4,1.5*m), size = 12)
ax1.hlines(y = 2.51*m, xmin = 4e-4, xmax = 7e-4, lw = 2, color = 'k', zorder = 150)


ax1.annotate("KARMEN", xy = (0.03,5.2e16), size = 12)
ax1.hlines(y = 17.7*m, xmin = 10e-3, xmax = 200e-3, lw = 2)

ax1.annotate("OscSNS", xy = (0.03,3.5e17), size = 12)
ax1.hlines(y = 3.15e17, xmin = 0.001, xmax = 0.05, lw = 2, zorder = 3)

ax1.annotate("JUNO", xy = (0.0035,1.75e20), size = 12)
ax1.hlines(y = 3.0e20, xmin = 0.0018, xmax = 0.012, lw = 2)

ax1.annotate("Daya Bay", xy = (0.0025,11.95e18), size = 14)
ax1.hlines(y = 9.9e18, xmin = 1.8e-3, xmax = 12e-3, lw = 2)

ax1.annotate("DAE"+"$\delta$"+"ALUS", xy = (0.015,4.6e19), size = 12)
ax1.hlines(y = 4.e19, xmin = 0.01, xmax = 0.06, lw = 2)

ax1.annotate("MiniBooNE", xy = (0.2,3.3e18), size = 12)
ax1.hlines(y = 2.8e18, xmin = 0.2, xmax = 3.0, lw = 2, zorder = 3, color = '#EF597B')
ax1.hlines(y = 2.8e18, xmin = 0.2, xmax = 3.0, lw = 2, zorder = 3, color = "k", linestyle = "dashed")

ax1.annotate('MicroBooNE', xy = (0.13,280*m), size = 12)
ax1.hlines(y = 470*m, xmin = 0.2, xmax = 3.0, lw = 2, color = 'k')


ax1.annotate("CDHS", xy = (1.2,3.9e17), size = 12)
ax1.hlines(y = 6.66e17, xmin = 1.0, xmax = 3.93, lw = 2)

ax1.annotate("MINER"+r"$\nu$"+"A", xy = (1,9.5e17), size = 12)
ax1.hlines(y = 1.63e18, xmin = 1.0, xmax = 20.22, lw = 2)

ax1.annotate("BNL-E776", xy = (2,3.2e18), size = 11)
ax1.hlines(y =4.77e18, xmin = 1.0, xmax = 5.0, lw = 2)

#ax1.annotate("NOMAD/CHORUS", xy = (30,1.7e18), size = 12)
#ax1.hlines(y =2.98e18, xmin = 10.0, xmax = 155.0, lw = 2)

#ax1.annotate("CCFR/NuTeV", xy = (45,6.5e18), size = 12)
#ax1.hlines(y =5.52e18, xmin = 30.0, xmax = 605.0, lw = 2)

ax1.annotate("K2K", xy = (0.7,0.75e21), size = 12)
ax1.hlines(y =1.26e21, xmin = 0.3, xmax = 2.52, lw = 2)

ax1.annotate("T2K", xy = (0.3,1.65e21), size = 12)
ax1.hlines(y =1.42e21, xmin = 0.25, xmax = 0.81, lw = 2)

ax1.annotate("MINOS/OPERA/ICARUS", xy = (0.55,2.1e21), size = 12)
ax1.hlines(y = 3.66e21, xmin = 0.97, xmax = 31.09, lw = 2)

ax1.annotate('MINOS (near)', xy = (1.,1.3*km), size = 12)
ax1.hlines(y = 1.04*km, xmin = 0.97, xmax = 31.09, lw = 2)

ax1.annotate("NO"+r"$\nu$"+"A", xy = (2.5,4.05e21), size = 11)
ax1.hlines(y = 4.1e21, xmin = 1.63, xmax = 2.38, lw = 2)

ax1.annotate("DUNE", xy = (2,7.3e21), size = 12)
ax1.hlines(y = 6.5e21, xmin = 0.5, xmax = 7.05, lw = 2)

ax1.annotate("PROSPECT", xy = (2.4e-3,1.7e16), size = 14)
ax1.hlines(y = 3.0e16, xmin = 1.8e-3, xmax = 1.2e-2, lw = 2)

ax1.annotate("IsoDAR", xy = (1.35e-2,9.5*m), size = 10.5, color = '#cd34b5')
#ax1.hlines(y = 10*m, xmin = 3.0e-3, xmax = 1.3e-2, lw = 2)
IsoDAR_patch = mpl.patches.Rectangle(xy = (3e-3,9.5*m), width = 10e-3, height = (25.6-9.5)*m, color = '#cd34b5', alpha = opa/2)
ax1.add_patch(IsoDAR_patch)

# patches

ax1.annotate("Solar Potential", xy = (0.9e-3,3.5e22), size = 12)
rec_solar = mpl.patches.Rectangle(xy = (3.0e-4,1.5e20), width = 0.01731, height = 10.35e22, color = '#FFCB18', alpha = opa)
ax1.add_patch(rec_solar)

ax1.annotate("KamLAND", xy = (0.0013,15.0e20), size = 12)
rec_KamLAND = mpl.patches.Rectangle(xy = (0.0018,7.22e20), width = 10.2e-3, height = 5.e20, fill = None, hatch = '///')
ax1.add_patch(rec_KamLAND)

ax1.annotate("Super-K", xy = (1.3,3.5e22), size = 12)
rec_SK = mpl.patches.Rectangle(xy = (0.21,1.5e20), width = 20.5, height = 18.0e22, color = '#73B66B', alpha = opa)
ax1.add_patch(rec_SK)

#ax1.annotate("IceCube", xy = (120.0,0.9e22), rotation = 90, size = 12, fontweight = "bold")
rec_icecube = mpl.patches.Rectangle(xy = (100.0,1.5e20), width = 10000.5, height = 18.0e22, color = '#29A2C6', alpha = opa)
#ax1.add_patch(rec_icecube)

#ax1.text(50.0,0.8e22,"DeepCore",rotation=90, size = 12, fontweight = "bold")
rec_deepcore = mpl.patches.Rectangle(xy = (10.0,1.5e20), width = 10000.5, height = 18.0e22, color = '#29A2C6', 
                                     alpha = opa-0.4)
#ax1.add_patch(rec_deepcore)

ax1.annotate("Bugey", xy = (2.5e-3,4.1e17), size = 12, color = '#8E2921',fontweight = "bold")
rec_reactor_2 = mpl.patches.Rectangle(xy = (1.8e-3,0.9e17), width = 10.2e-3, height = 2.8e17, color = '#FA8775', alpha = opa)
ax1.add_patch(rec_reactor_2)

ax1.annotate(" Double Chooz \n Palo Verde \n RENO", xy = (2.0e-3,1.5e18), size = 12)
rec_reactor_1 = mpl.patches.Rectangle(xy = (1.8e-3,2.0e18), width = 10.2e-3, height = 6.6e18, color = '#FFB14E', alpha = opa)
ax1.add_patch(rec_reactor_1)

ax2 = ax1.twinx()
ax2.loglog()
ax2.set_xlim(5.0e-4,0.7e3)
ax2.set_xlim(3.0e-4,0.7e1)
ax2.set_ylim(0.2e16/(GeV*m),1.0e23/(GeV*m))
ax2.set_ylabel(r"$L\ [\mathrm{m}] $")

solar = 4*(enu)/(Deltam21)*2*np.pi
atm = 4*enu/(Deltam31)*2*np.pi
ste = 4*enu/(Deltam41)*2*np.pi

ax1.annotate(r"$L_\odot^{\text{osc}}$", xy = (0.025,2.0e22), size = 20, fontweight = "bold", color = 'gray')
#ax1.plot(EE/GeV,2.0*np.pi*(EE/dmsq_sun)*GeV, lw = 3.5, color = 'k', ls = "dashed")
ax1.plot(enu,solar, lw = 3.5, color = 'gray', ls = "dotted")

ax1.annotate(r"$L_{\text{atm}}^{\text{osc}}$", xy = (0.025,0.65e21), size = 20, fontweight = "bold", color = 'gray')
ax1.plot(enu,atm, lw = 3.5, color = 'gray', ls = "dotted")

ax1.annotate(r"$L_{\text{ste}}^{\text{osc}}$", xy = (0.5,3e19), size = 20, fontweight = "bold", color = color2)
ax1.plot(enu,ste, lw = 3.5, color = color2, ls = "dashed", zorder = 100)

sigma = 2.1e-4*nm
enu_nuc = np.logspace(np.log10(3e-4*GeV),np.log10(1.5e-2*GeV),20)
decoh = 4*np.sqrt(2)*enu_nuc**2*sigma/Deltam41
ax1.plot(enu_nuc,decoh, lw = 3.5, color = color3, ls = "dashed", zorder = 100)
ax1.fill_between(enu_nuc,decoh,1e23,color = color3, alpha = 0.05)
x1 = 1.25e-3/GeV
x2 = 7e-4/GeV
y1 = 0.9e16*GeV
y2 = 7e16*GeV
ax1.annotate(r"$L_{\text{ste}}^{\text{coh,nuc}}$", xy = (0.016,1.4e18), size = 20, fontweight = "bold", color = color3)
#x1.arrow(x1,y1,x2-x1,y2-y1, length_includes_head=True,head_length= 6e15,color = color3)

#ax1.arrow(0.02,0.25e19,0,0.8e19, head_length= 6e18, color = color3)
ax1.annotate("", xy=(x1,y2), xytext=(x1,y1),arrowprops=dict(arrowstyle="->", color = color3, lw = 3), zorder = 101)
#ax1.annotate("", xy=(x2,y2), xytext=(x1,y1),arrowprops=dict(arrowstyle="->", color = color3, lw = 3))


# pion coherence length
enu_pi = np.logspace(np.log10(60e-3*GeV),np.log10(10*GeV),20)
sigma_pi = 1e-11*m
m_pi = 139.6e-3*GeV
m_mu = 105.7e-3*GeV
decoh_pi = 2*np.sqrt(2)*enu_pi**2*(m_pi**2-m_mu**2)*sigma_pi/m_pi**2/Deltam41
ax1.plot(enu_pi,decoh_pi, lw = 3.5, color = color3, ls = "dashed", zorder = 100)
ax1.annotate(r"$L_{\text{ste}}^{\text{coh,}\pi\text{ flight}}$", xy = (0.07,4e21), size = 20, fontweight = "bold", color = color3)
ax1.fill_between(enu_pi,decoh_pi,1e23,color = color3, alpha = 0.05)
ax1.annotate("", xy=(0.41,0.7e23), xytext=(0.41,1.e22),arrowprops=dict(arrowstyle="->", color = color3, lw = 3))
#ax1.annotate("", xy=(0.3,0.8e23), xytext=(0.49,1.4e22),arrowprops=dict(arrowstyle="->", color = color3, lw = 3))


ax1.annotate("Nuclear decay", xy = (1e-3, 2.5e23), xycoords = 'data', annotation_clip = False)
ax1.annotate(r"$\pi$ decay"+"\n at rest", xy = (5.3e-2, 2.0e23), ha = 'right', xycoords = 'data', annotation_clip = False)
ax1.annotate(r"$\pi$ decay in flight", xy = (2.2e-1, 2.5e23), xycoords = 'data', annotation_clip = False)
ax1.annotate('', xy=(1.99e-2,1.7e23), xytext=(3.01e-4,1.7e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)
ax1.annotate('', xy=(61e-3,1.3e23), xytext=(1.01e-2,1.3e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)
ax1.annotate('', xy=(59e-3,1.7e23), xytext=(6.9e0,1.7e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)

#ax1.grid(linestyle = '-.')
#plt.show()
plt.savefig('All_experiments.pdf', dpi = 600, bbox_inches = 'tight')
plt.savefig('All_experiments.png', dpi = 600, bbox_inches = 'tight')

# %%
margins = dict(left=0.15, right=0.97,bottom=0.19, top=0.7)
px = 1/plt.rcParams['figure.dpi']
ts = 18
fig,ax1 = plt.subplots(figsize = (1000*px,650*px)) 

#ax1 = fig.add_subplot(111)

opa = 0.3

enu = np.logspace(np.log10(3e-4*GeV),np.log10(7*GeV),20)
Deltam21 = 7.42e-5*eV**2
Deltam31 = 2.514e-3*eV**2
Deltam41 = 1*eV**2

ax1.set_xlim(5.0e-4,0.9e3)
ax1.set_ylim(0.2e16,1.0e23)
ax1.loglog()

ax1.set_xlabel(r"$E_\nu [\mathrm{GeV}] $", fontsize = 20)
ax1.set_ylabel(r"$L\ [\mathrm{GeV}^{-1}] $", fontsize = 20)

ax1.annotate("LSND", xy = (0.05,1.7e17), size = ts)
ax1.hlines(y = 1.5e17, xmin = 1.0e-2, xmax = 0.2, lw = 4, color = '#EF597B')
ax1.hlines(y = 1.5e17, xmin = 1.0e-2, xmax = 0.2, lw = 4, color = "k", linestyle = "dashed")

ax1.annotate("NEOS", xy = (1.8e-3,30*m), size = ts)
ax1.hlines(y = 23.7*m, xmin = 1.8e-3, xmax = 1.2e-2, lw = 4, color = 'k')

#ax1.annotate('Neutrino-4', xy = (0.004,9*m), size = 12)
#ax1.hlines(y = 8*m, xmin = 1.8e-3, xmax = 1.2e-2, lw = 2, color = 'k')


ax1.annotate('BEST', xy = (3.5e-4,0.6*m), size = ts, zorder = 200)
ax1.hlines(y = 0.5*m, xmin = 4e-4, xmax = 7e-4, lw = 4, color = 'k')

#ax1.annotate('SAGE', xy = (3.4e-4,0.78*m), size = 12)
#ax1.hlines(y = 0.71*m, xmin = 4e-4, xmax = 7e-4, lw = 2, color = 'k')

ax1.annotate('GALLEX', xy = (3.5e-4,3*m), size = ts, zorder = 121)
ax1.hlines(y = 2.51*m, xmin = 4e-4, xmax = 7e-4, lw = 4, color = 'k', zorder = 150)


#ax1.annotate("KARMEN", xy = (0.03,5.2e16), size = 12)
#ax1.hlines(y = 17.7*m, xmin = 10e-3, xmax = 200e-3, lw = 2)

ax1.annotate("JUNO", xy = (0.0035,1.55e20), size = ts)
ax1.hlines(y = 3.0e20, xmin = 0.0018, xmax = 0.012, lw = 4)

ax1.annotate("Daya Bay", xy = (0.0025,11.95e18), size = ts)
ax1.hlines(y = 9.9e18, xmin = 1.8e-3, xmax = 12e-3, lw = 4)

ax1.annotate("DAE"+"$\delta$"+"ALUS", xy = (0.01,4.6e19), size = ts)
ax1.hlines(y = 4.e19, xmin = 0.01, xmax = 0.06, lw = 4)

ax1.annotate("MiniBooNE", xy = (0.2,3.3e18), size = ts)
ax1.hlines(y = 2.8e18, xmin = 0.2, xmax = 3.0, lw = 4, zorder = 3, color = '#EF597B')
ax1.hlines(y = 2.8e18, xmin = 0.2, xmax = 3.0, lw = 4, zorder = 3, color = "k", linestyle = "dashed")

#ax1.annotate('MicroBooNE', xy = (0.13,280*m), size = 12)
#ax1.hlines(y = 470*m, xmin = 0.2, xmax = 3.0, lw = 4, color = 'k')


#ax1.annotate("CDHS", xy = (1.2,3.9e17), size = 12)
#ax1.hlines(y = 6.66e17, xmin = 1.0, xmax = 3.93, lw = 2)

#ax1.annotate("MINER"+r"$\nu$"+"A", xy = (1,9.5e17), size = 12)
#ax1.hlines(y = 1.63e18, xmin = 1.0, xmax = 20.22, lw = 2)

#ax1.annotate("BNL-E776", x = (2,3.2e18), size = 11)
#ax1.hlines(y =4.77e18, xmin = 1.0, xmax = 5.0, lw = 2)

#ax1.annotate("NOMAD/CHORUS", xy = (30,1.7e18), size = 12)
#ax1.hlines(y =2.98e18, xmin = 10.0, xmax = 155.0, lw = 2)

#ax1.annotate("CCFR/NuTeV", xy = (45,6.5e18), size = 12)
#ax1.hlines(y =5.52e18, xmin = 30.0, xmax = 605.0, lw = 2)

ax1.annotate("K2K", xy = (0.7,0.6e21), size = ts)
ax1.hlines(y =1.26e21, xmin = 0.3, xmax = 2.52, lw = 4)

#ax1.annotate("T2K", xy = (0.3,1.65e21), size = 12)
#ax1.hlines(y =1.42e21, xmin = 0.25, xmax = 0.81, lw = 2)

ax1.annotate("MINOS (far)", xy = (1.1,1.8e21), size = ts)
ax1.hlines(y = 3.66e21, xmin = 0.97, xmax = 31.09, lw = 4)

ax1.annotate('MINOS (near)', xy = (1.,1.3*km), size = ts)
ax1.hlines(y = 1.04*km, xmin = 0.97, xmax = 31.09, lw = 4)

#ax1.annotate("NO"+r"$\nu$"+"A", xy = (2.5,4.05e21), size = 11)
#ax1.hlines(y = 4.1e21, xmin = 1.63, xmax = 2.38, lw = 2)

ax1.annotate("DUNE", xy = (2,7.3e21), size = 16)
ax1.hlines(y = 6.5e21, xmin = 0.5, xmax = 7.05, lw = 4)

ax1.annotate("PROSPECT", xy = (2.4e-3,1.6e16), size = ts)
ax1.hlines(y = 3.0e16, xmin = 1.8e-3, xmax = 1.2e-2, lw = 4)

ax1.annotate("IsoDAR", xy = (1.35e-2,9.5*m), size = ts)
ax1.hlines(y = 10*m, xmin = 3.0e-3, xmax = 1.3e-2, lw = 4)
#IsoDAR_patch = mpl.patches.Rectangle(xy = (3e-3,9.5*m), width = 10e-3, height = (25.6-9.5)*m, lw = 4, color = '#cd34b5', alpha = opa/2)
#ax1.add_patch(IsoDAR_patch)

# patches

ax1.annotate("Solar Potential", xy = (0.9e-3,3.5e22), size = ts)
rec_solar = mpl.patches.Rectangle(xy = (3.0e-4,1.5e20), width = 0.01731, height = 10.35e22, color = '#FFCB18', alpha = opa)
ax1.add_patch(rec_solar)

ax1.annotate("KamLAND", xy = (0.0018,15.0e20), size = ts)
rec_KamLAND = mpl.patches.Rectangle(xy = (0.0018,7.22e20), width = 10.2e-3, height = 5.e20, fill = None, hatch = '///')
ax1.add_patch(rec_KamLAND)

ax1.annotate("Super-K", xy = (1.8,3.5e22), size = ts)
rec_SK = mpl.patches.Rectangle(xy = (0.21,1.5e20), width = 20.5, height = 18.0e22, color = '#73B66B', alpha = opa)
ax1.add_patch(rec_SK)

#ax1.annotate("IceCube", xy = (120.0,0.9e22), rotation = 90, size = 12, fontweight = "bold")
rec_icecube = mpl.patches.Rectangle(xy = (100.0,1.5e20), width = 10000.5, height = 18.0e22, color = '#29A2C6', alpha = opa)
#ax1.add_patch(rec_icecube)

#ax1.text(50.0,0.8e22,"DeepCore",rotation=90, size = 12, fontweight = "bold")
rec_deepcore = mpl.patches.Rectangle(xy = (10.0,1.5e20), width = 10000.5, height = 18.0e22, color = '#29A2C6', 
                                     alpha = opa-0.4)
#ax1.add_patch(rec_deepcore)

ax1.annotate("Bugey", xy = (2.5e-3,100*m), size = ts, fontweight = "bold")
ax1.hlines(y = 80*m, xmin = 1.8e-3, xmax = 10.2e-3, lw = 4)
#rec_reactor_2 = mpl.patches.Rectangle(xy = (1.8e-3,0.9e17), width = 10.2e-3, height = 2.8e17, color = '#FA8775', alpha = opa)
#ax1.add_patch(rec_reactor_2)

ax1.annotate("Double Chooz \n RENO", xy = (1.9e-3,1.7e18), size = ts)
rec_reactor_1 = mpl.patches.Rectangle(xy = (1.8e-3,2.0e18), width = 10.2e-3, height = 6.6e18, color = '#FFB14E', alpha = opa)
ax1.add_patch(rec_reactor_1)

ax2 = ax1.twinx()
ax2.loglog()
ax2.set_xlim(5.0e-4,0.7e3)
ax2.set_xlim(3.0e-4,0.7e1)
ax2.set_ylim(0.2e16/(GeV*m),1.0e23/(GeV*m))
ax2.set_ylabel(r"$L\ [\mathrm{m}] $", fontsize = 20)

solar = 4*(enu)/(Deltam21)*2*np.pi
atm = 4*enu/(Deltam31)*2*np.pi
ste = 4*enu/(Deltam41)*2*np.pi

#ax1.annotate(r"$L_\odot^{\text{osc}}$", xy = (0.025,2.0e22), size = 20, fontweight = "bold", color = 'gray')
#ax1.plot(EE/GeV,2.0*np.pi*(EE/dmsq_sun)*GeV, lw = 3.5, color = 'k', ls = "dashed")
#ax1.plot(enu,solar, lw = 3.5, color = 'gray', ls = "dotted")

#ax1.annotate(r"$L_{\text{atm}}^{\text{osc}}$", xy = (0.025,0.65e21), size = 20, fontweight = "bold", color = 'gray')
#ax1.plot(enu,atm, lw = 3.5, color = 'gray', ls = "dotted")

ax1.annotate(r"$L_{\text{ste}}^{\text{osc}}$", xy = (7e-2,120*m), size = 24, fontweight = "bold", color = color2)
ax1.plot(enu,ste, lw = 3.5, color = color2, ls = "dashed", zorder = 100)

nmax = 10
for fac in np.logspace(0,2,nmax):
    ax1.fill_between(enu,ste,ste*fac,color = color2, alpha = 0.05, lw=0, zorder = 1)
    ax1.fill_between(enu,ste/fac,ste,color = color2, alpha = 0.05, lw=0, zorder = 1)

#ax1.fill_between(enu,ste/1e2,ste*1e2, color = color2, alpha = 0.05, zorder = 49)
#for x in range(nmax):
#    fac = x/nmax*100
#    ax1.fill_between(enu,ste,ste*fac,color = color2, alpha = 0.0*fac/100, lw=0, zorder = 50)
#    ax1.fill_between(enu,ste,ste/fac,color = color2, alpha = 0.03*fac/100, lw=0, zorder = 50)

sigma = 2.1e-4*nm
enu_nuc = np.logspace(np.log10(3e-4*GeV),np.log10(1.7e-2*GeV),20)
decoh = 4*np.sqrt(2)*enu_nuc**2*sigma/Deltam41
ax1.plot(enu_nuc,decoh, lw = 3.5, color = color3, ls = "dashed", zorder = 100)

ax1.fill_between(enu_nuc,decoh,1e23,color = color3, alpha = 0.18, zorder = 2)
x1 = 1.25e-3/GeV
x2 = 7e-4/GeV
y1 = 0.9e16*GeV
y2 = 7e16*GeV
ax1.annotate(r"$L_{\text{ste}}^{\text{coh,nuc}}$", xy = (1.3e-3,0.8*m), size = 24, 
             fontweight = "bold", color = color3)
#x1.arrow(x1,y1,x2-x1,y2-y1, length_includes_head=True,head_length= 6e15,color = color3)

#ax1.arrow(0.02,0.25e19,0,0.8e19, head_length= 6e18, color = color3)
#ax1.annotate("", xy=(x1,y2), xytext=(x1,y1),arrowprops=dict(arrowstyle="->", color = color3, lw = 3), zorder = 101)
#ax1.annotate("", xy=(x2,y2), xytext=(x1,y1),arrowprops=dict(arrowstyle="->", color = color3, lw = 3))


# pion coherence length
enu_pi = np.logspace(np.log10(60e-3*GeV),np.log10(10*GeV),20)
sigma_pi = 1e-11*m
m_pi = 139.6e-3*GeV
m_mu = 105.7e-3*GeV
decoh_pi = 2*np.sqrt(2)*enu_pi**2*(m_pi**2-m_mu**2)*sigma_pi/m_pi**2/Deltam41
ax1.plot(enu_pi,decoh_pi, lw = 3.5, color = color3, ls = "dashed", zorder = 100)
ax1.annotate(r"$L_{\text{ste}}^{\text{coh,}\pi\text{ flight}}$", xy = (0.07,3e21), size = 22, fontweight = "bold", color = color3)
ax1.fill_between(enu_pi,decoh_pi,1e23,color = color3, alpha = 0.15)
#ax1.annotate("", xy=(0.41,0.7e23), xytext=(0.41,1.e22),arrowprops=dict(arrowstyle="->", color = color3, lw = 3))
#ax1.annotate("", xy=(0.3,0.8e23), xytext=(0.49,1.4e22),arrowprops=dict(arrowstyle="->", color = color3, lw = 3))


ax1.annotate("Nuclear decay", xy = (1e-3, 2.5e23), xycoords = 'data', annotation_clip = False)
ax1.annotate(r"$\pi$ decay"+"\n at rest", xy = (5.3e-2, 2.0e23), ha = 'right', xycoords = 'data', annotation_clip = False)
ax1.annotate(r"$\pi$ decay in flight", xy = (2.2e-1, 2.5e23), xycoords = 'data', annotation_clip = False)
ax1.annotate('', xy=(1.99e-2,1.7e23), xytext=(3.01e-4,1.7e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)
ax1.annotate('', xy=(61e-3,1.3e23), xytext=(1.01e-2,1.3e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)
ax1.annotate('', xy=(59e-3,1.7e23), xytext=(6.9e0,1.7e23), arrowprops=dict(arrowstyle='<->', lw = 1), annotation_clip = False)

#ax1.grid(linestyle = '-.')
#plt.show()
#plt.savefig('All_experiments.pdf', dpi = 600, bbox_inches = 'tight')
plt.savefig('All_experiments_poster.png', dpi = 600, bbox_inches = 'tight')
